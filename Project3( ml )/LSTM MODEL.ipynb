# %%
pip install alpha_vantage
# Out:
# ...
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from alpha_vantage.timeseries import TimeSeries
import yfinance as yf
import pandas_datareader as data

# %%
#api_key = '3E9LKF0R4UNQAJJZ'

# Initialize the TimeSeries class with the API key
#ts = TimeSeries(key=api_key, output_format='pandas')

# Get historical daily data for the TSLA stock
#data, meta_data = ts.get_daily_adjusted('TSLA', outputsize='full')
#data = data.loc['2010-01-01':'2019-12-31']
#df = pd.DataFrame(data)
#df.head(10)
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_5496\52441383.py:8: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   data = data.loc['2010-01-01':'2019-12-31']
#             1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# date
# 2019-12-31   405.00   421.29  402.08    418.33          27.888667  10292456.0
# 2019-12-30   428.79   429.00  409.26    414.70          27.646667  12601265.0
# 2019-12-27   435.00   435.31  426.11    430.38          28.692000   9956827.0
# 2019-12-26   427.91   433.48  426.35    430.94          28.729333  10648289.0
# 2019-12-24   418.36   425.47  412.69    425.25          28.350000   8054720.0
# 2019-12-23   411.78   422.01  410.00    419.22          27.948000  13332821.0
# 2019-12-20   410.29   413.00  400.19    405.59          27.039333  14785206.0
# ...

# %%
start = '2010-01-01'
end = '2019-12-31'
stock = "AAPL"
src = "yahoo"
#df = data.DataReader(stock,src,start,end)
data = yf.download(stock, start, end)
data.reset_index(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-01-04 00:00:00-05:00  7.622500  7.660714  7.585000  7.643214
# 1 2010-01-05 00:00:00-05:00  7.664286  7.699643  7.616071  7.656429
# 2 2010-01-06 00:00:00-05:00  7.656429  7.686786  7.526786  7.534643
# 3 2010-01-07 00:00:00-05:00  7.562500  7.571429  7.466071  7.520714
# 4 2010-01-08 00:00:00-05:00  7.510714  7.571429  7.466429  7.570714
#
#    Adj Close     Volume
# 0   6.515212  493729600
# 1   6.526476  601904800
# 2   6.422664  552160000
# 3   6.410790  477131200
# 4   6.453411  447610800

# %%
#df = df.reset_index()
#df.head(10)

# %%
#column_names = df.columns
#print(column_names)

# %%
#df.drop('8. split coefficient', axis=1, inplace=True)

# %%
#df.drop('7. dividend amount', axis=1, inplace=True)

# %%
#df = df.drop('5. adjusted close',axis=1)

# %%
#df = df.drop('date',axis=1)

# %%
#df.head()

# %%
#df = df.loc[::-1,:]

# %%
#df = df.reset_index()
#df.head(10)

# %%
#df = df.drop('index',axis=1)

# %%
#df = df.rename(columns={'1. open': 'open', '2. high': 'high','3. low':'low','4. close':'close','6. volume':'volume'})

# %%
#column_names = df.columns
#print(column_names)

# %%
#df.head()

# %%
df
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2010-01-04 00:00:00-05:00   7.622500   7.660714   7.585000   7.643214
# 1    2010-01-05 00:00:00-05:00   7.664286   7.699643   7.616071   7.656429
# 2    2010-01-06 00:00:00-05:00   7.656429   7.686786   7.526786   7.534643
# 3    2010-01-07 00:00:00-05:00   7.562500   7.571429   7.466071   7.520714
# 4    2010-01-08 00:00:00-05:00   7.510714   7.571429   7.466429   7.570714
# ...                        ...        ...        ...        ...        ...
# 2510 2019-12-23 00:00:00-05:00  70.132500  71.062500  70.092499  71.000000
# 2511 2019-12-24 00:00:00-05:00  71.172501  71.222504  70.730003  71.067497
# 2512 2019-12-26 00:00:00-05:00  71.205002  72.495003  71.175003  72.477501
# 2513 2019-12-27 00:00:00-05:00  72.779999  73.492500  72.029999  72.449997
# 2514 2019-12-30 00:00:00-05:00  72.364998  73.172501  71.305000  72.879997
#
#       Adj Close     Volume
# 0      6.515212  493729600
# ...

# %%
plt.plot(df.Close)

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2510    59.201075
# 2511    59.401700
# 2512    59.643125
# 2513    59.875125
# 2514    60.106325
# Name: Close, Length: 2515, dtype: float64

# %%
plt.figure(figsize = (5,3))
plt.plot(df.Close)
plt.plot(ma100 ,'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2510    54.132313
# 2511    54.261513
# 2512    54.396763
# 2513    54.529350
# 2514    54.661100
# Name: Close, Length: 2515, dtype: float64

# %%
plt.figure(figsize = (8,4))
plt.plot(df.Close)
plt.plot(ma100 ,'r')
plt.plot(ma200 ,'g')

# %%
df.shape
# Out:
# (2515, 7)

# %%
# splitting data into training and testing
 
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1760, 1)
# (755, 1)

# %%
data_training.head()
# Out:
#       Close
# 0  7.643214
# 1  7.656429
# 2  7.534643
# 3  7.520714
# 4  7.570714

# %%
data_testing.head()
# Out:
#           Close
# 1760  29.182501
# 1761  28.955000
# 1762  29.037500
# 1763  29.004999
# 1764  29.152500

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.02971782],
#        [0.03021854],
#        [0.02560389],
#        ...,
#        [0.84388656],
#        [0.85089656],
#        [0.84616011]])

# %%
x_train = []
y_train = []

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])
    
x_train , y_train = np.array(x_train) , np.array(y_train)

# %%
x_train.shape
# Out:
# (1660, 100, 1)

# %%
# ML model

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda keras
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#      ------------------------------------ 266.3/266.3 MB 652.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 774.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.0/6.0 MB 971.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 23.2/23.2 MB 1.1 MB/s eta 0:00:00
# ...
#      ------------------------------------ 895.9/895.9 kB 995.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 439.2/439.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.7/3.7 MB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.5/126.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 177.8/177.8 kB 2.7 MB/s eta 0:00:00
# ...

# %%
conda update keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Pranav\anaconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-2.0.2|   py39haa95532_0         286 KB
#     conda-package-streaming-0.7.0|   py39haa95532_0          27 KB
#     conda-repo-cli-1.0.27      |   py39haa95532_0         130 KB
#     keras-2.10.0               |   py39haa95532_0         1.5 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     ruamel.yaml-0.17.21        |   py39h2bbff1b_0         174 KB
#     zstandard-0.18.0           |   py39h2bbff1b_0         310 KB
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# ...

# %%
from keras.layers import Dense , Dropout ,LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units=50,activation = 'relu',return_sequences = True,
              input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=60,activation = 'relu',return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units=80,activation = 'relu',return_sequences = True))
model.add(Dropout(0.4))


model.add(LSTM(units=120,activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam' , loss = 'mean_squared_error')
model.fit(x_train,y_train,epochs = 50)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 47s 389ms/step - loss: 0.0700
# Epoch 2/50
# 52/52 [==============================] - 15s 294ms/step - loss: 0.0130
# Epoch 3/50
# 52/52 [==============================] - 15s 281ms/step - loss: 0.0119
# Epoch 4/50
# 52/52 [==============================] - 15s 283ms/step - loss: 0.0098
# Epoch 5/50
# 52/52 [==============================] - 17s 318ms/step - loss: 0.0101
# Epoch 6/50
# 52/52 [==============================] - 17s 320ms/step - loss: 0.0086
# Epoch 7/50
# 52/52 [==============================] - 17s 319ms/step - loss: 0.0088
# Epoch 8/50
# 52/52 [==============================] - 18s 343ms/step - loss: 0.0084
# Epoch 9/50
# 52/52 [==============================] - 18s 346ms/step - loss: 0.0082
# Epoch 10/50
# 52/52 [==============================] - 16s 302ms/step - loss: 0.0069
# Epoch 11/50
# 52/52 [==============================] - 16s 317ms/step - loss: 0.0072
# Epoch 12/50
# ...

# %%
model.save('keras_model.hs')
# Out:
# INFO:tensorflow:Assets written to: keras_model.hs\assets

# %%
data_testing.head()
# Out:
#           Close
# 1760  29.182501
# 1761  28.955000
# 1762  29.037500
# 1763  29.004999
# 1764  29.152500

# %%
past_100_days = data_training.tail(100)

# %%
final_df = past_100_days.append(data_testing,ignore_index = True)
# Out:
# C:\Users\Pranav\AppData\Local\Temp\ipykernel_5496\1195911748.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = past_100_days.append(data_testing,ignore_index = True)

# %%
final_df.head()
# Out:
#        Close
# 0  27.092501
# 1  27.202499
# 2  27.000000
# 3  26.982500
# 4  27.045000

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.02781467],
#        [0.03015022],
#        [0.02585064],
#        [0.02547908],
#        [0.02680611],
#        [0.03370671],
#        [0.03317586],
#        [0.03232658],
#        [0.03158344],
#        [0.03306972],
#        [0.02855781],
#        [0.03036255],
#        [0.02600988],
#        [0.02356814],
#        [0.02022403],
#        [0.01958704],
#        [0.01523437],
#        [0.01576518],
#        [0.01910933],
#        [0.02441747],
#        [0.02425819],
#        [0.02776158],
#        [0.01268645],
#        [0.        ],
#        [0.01226183],
#        [0.02558522],
#        [0.04586231],
#        [0.06603324],
#        [0.06258295],
#        [0.05547006],
#        [0.05541697],
#        [0.05531082],
#        [0.06099053],
#        [0.05085197],
#        [0.05175434],
#        [0.05286905],
#        [0.05743405],
#        [0.04803866],
#        [0.05265676],
#        [0.04984341],
#        [0.05239133],
#        [0.05265676],
#        [0.05711557],
# ...

# %%
input_data.shape
# Out:
# (855, 1)

# %%
x_test = []
y_test = []

for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
x_test , y_test = np.array(x_test) , np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (755, 100, 1)
# (755,)

# %%
#making predictions

y_predicted = model.predict(x_test)
# Out:
# 24/24 [==============================] - 2s 52ms/step

# %%
y_predicted.shape
# Out:
# (755, 1)

# %%
y_test
# Out:
# array([0.0721907 , 0.06736028, 0.06911197, 0.06842189, 0.07155371,
#        0.07845431, 0.08418707, 0.08482406, 0.08822126, 0.08556719,
#        0.08445249, 0.0895483 , 0.0894952 , 0.0883805 , 0.0895483 ,
#        0.08997296, 0.08938906, 0.09952758, 0.0998461 , 0.09989915,
#        0.09820055, 0.09671427, 0.1359945 , 0.1348267 , 0.1377462 ,
#        0.144169  , 0.15075112, 0.15345824, 0.15547536, 0.1538829 ,
#        0.16009341, 0.16927655, 0.17187748, 0.17102824, 0.17299223,
#        0.17819418, 0.18037053, 0.1772918 , 0.17798189, 0.17941503,
#        0.17973358, 0.1945963 , 0.19019062, 0.19454325, 0.19220766,
#        0.19316316, 0.19040291, 0.18870427, 0.19114605, 0.19146452,
#        0.19034986, 0.19815283, 0.19937368, 0.195658  , 0.20346096,
#        0.19486173, 0.20324859, 0.20059453, 0.19910825, 0.20038224,
#        0.21588199, 0.21758055, 0.21657199, 0.21513885, 0.21535114,
#        0.22103089, 0.21704978, 0.21513885, 0.21344021, 0.21253783,
# ...

# %%
y_predicted
# Out:
# array([[0.1768798 ],
#        [0.17765763],
#        [0.17830418],
#        [0.17875141],
#        [0.17894858],
#        [0.17892647],
#        [0.17871383],
#        [0.17841244],
#        [0.17813334],
#        [0.17796983],
#        [0.177975  ],
#        [0.17813337],
#        [0.17843512],
#        [0.17887238],
#        [0.17941865],
#        [0.18001944],
#        [0.18063599],
#        [0.18122727],
#        [0.18179354],
#        [0.18234211],
#        [0.18287975],
#        [0.18340786],
#        [0.18391997],
#        [0.18445739],
#        [0.18509957],
#        [0.18592282],
#        [0.18699527],
#        [0.18832177],
#        [0.18994632],
#        [0.19189575],
#        [0.19415489],
#        [0.19668731],
#        [0.19945216],
#        [0.20240265],
#        [0.20548245],
#        [0.2086237 ],
#        [0.21176142],
#        [0.21484   ],
#        [0.21781024],
#        [0.2206316 ],
#        [0.22325821],
#        [0.22567102],
#        [0.22788082],
# ...

# %%
scaler.scale_
# Out:
# array([0.02123255])

# %%
scale_factor = 1/0.02123255
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'y',label = 'Original price')
plt.plot(y_predicted,'g',label = 'Predicted price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
